# %% [markdown]
# ## 1. 영화 데이터 전처리 + 병합

# %% [markdown]
# #### 1-1. DATE -> YEAR

# %%
movie = pd.read_csv("movie_chart_all.csv")
movie.head()
# Out:
#    rank          name        date             sale    audience screen  \
# 0     1            명량  2014-07-30  135,748,398,910  17,613,682  1,587
# 1     2          겨울왕국  2014-01-16   82,461,504,400  10,296,101  1,010
# 2     3         인터스텔라  2014-11-06   80,671,424,300  10,105,247  1,410
# 3     4  해적: 바다로 간 산적  2014-08-06   66,370,682,706   8,666,046    910
# 4     5        수상한 그녀  2014-01-22   62,705,348,249   8,657,982  1,027
#
#   screen_number
# 0       188,611
# 1       157,683
# 2       166,218
# 3       133,350
# 4       136,975

# %%
movie['date'] = pd.to_datetime(movie['date'], errors='coerce').dt.year

movie.head()
# Out:
#    rank          name  date             sale    audience screen screen_number
# 0     1            명량  2014  135,748,398,910  17,613,682  1,587       188,611
# 1     2          겨울왕국  2014   82,461,504,400  10,296,101  1,010       157,683
# 2     3         인터스텔라  2014   80,671,424,300  10,105,247  1,410       166,218
# 3     4  해적: 바다로 간 산적  2014   66,370,682,706   8,666,046    910       133,350
# 4     5        수상한 그녀  2014   62,705,348,249   8,657,982  1,027       136,975

# %%
movie = pd.DataFrame({
    "rank": movie["rank"],
    "name": movie["name"],
    "year": movie["date"],
    "sale": movie["sale"],
    "audience": movie["audience"],
    "screen": movie["screen"],
    "screen_number": movie["screen_number"],
})

movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           500 non-null    int64
#  1   name           500 non-null    object
#  2   year           500 non-null    int32
#  3   sale           500 non-null    object
#  4   audience       500 non-null    object
#  5   screen         500 non-null    object
#  6   screen_number  500 non-null    object
# dtypes: int32(1), int64(1), object(5)
# memory usage: 25.5+ KB

# %%
# 매출, 관객, 스크린, 스크린 수에서 , 제거 
movie['sale'] = movie.sale.str.replace(',','')
movie['audience'] = movie.audience.str.replace(',','')
movie['screen'] = movie.screen.str.replace(',','')
movie['screen_number'] = movie.screen_number.str.replace(',','')
movie.head()
# Out:
#    rank          name  year          sale  audience screen screen_number
# 0     1            명량  2014  135748398910  17613682   1587        188611
# 1     2          겨울왕국  2014   82461504400  10296101   1010        157683
# 2     3         인터스텔라  2014   80671424300  10105247   1410        166218
# 3     4  해적: 바다로 간 산적  2014   66370682706   8666046    910        133350
# 4     5        수상한 그녀  2014   62705348249   8657982   1027        136975

# %%
#int로 바꿔주기 

movie=movie.astype(dtype={
                          'sale':'int',
                          'audience':'int',
                          'screen':'int',
                          'screen_number':'int'
                          })

movie.index.name='id'

movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           500 non-null    int64
#  1   name           500 non-null    object
#  2   year           500 non-null    int32
#  3   sale           500 non-null    int64
#  4   audience       500 non-null    int64
#  5   screen         500 non-null    int64
#  6   screen_number  500 non-null    int64
# dtypes: int32(1), int64(5), object(1)
# memory usage: 25.5+ KB

# %%
movie.head()
# Out:
#     rank          name  year          sale  audience  screen  screen_number
# id
# 0      1            명량  2014  135748398910  17613682    1587         188611
# 1      2          겨울왕국  2014   82461504400  10296101    1010         157683
# 2      3         인터스텔라  2014   80671424300  10105247    1410         166218
# 3      4  해적: 바다로 간 산적  2014   66370682706   8666046     910         133350
# 4      5        수상한 그녀  2014   62705348249   8657982    1027         136975

# %%
movie.to_csv("movie_chart.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# #### 1-2. 장르 칼럼 추가하고 합쳐주기

# %%
genre_all = pd.read_csv('../data/movie_genre_data.csv')
genre_all.head()
# Out:
#    Unnamed: 0     Name  Year                 Genre     Viewers
# 0           0  7번방의 선물  2013        ['코미디', '드라마']  12,811,206
# 1           1     설국열차  2013          ['SF', '액션']   9,349,993
# 2           2       관상  2013         ['사극', '드라마']   9,134,238
# 3           3   아이언맨 3  2013  ['액션', '어드벤처', 'SF']   9,001,331
# 4           4      베를린  2013                ['액션']   7,166,290

# %%
genre = genre_all[genre_all['Year'].between(2014,2023)]

genre
genre.to_csv("genre_2014_2023.csv", index=False, encoding="utf-8-sig")

# %%
movie
# Out:
#      rank                      name  year          sale  audience  screen  \
# id
# 0       1                        명량  2014  135748398910  17613682    1587
# 1       2                      겨울왕국  2014   82461504400  10296101    1010
# 2       3                     인터스텔라  2014   80671424300  10105247    1410
# 3       4              해적: 바다로 간 산적  2014   66370682706   8666046     910
# 4       5                    수상한 그녀  2014   62705348249   8657982    1027
# ..    ...                       ...   ...           ...       ...     ...
# 495    46  오늘 밤, 세계에서 이 사랑이 사라진다 해도  2022    5198084474    514915     402
# 496    47                    3일의 휴가  2023    4835070689    514541     863
# 497    48                       소년들  2023    4470423586    471425    1042
# 498    49                      타이타닉  1998    6528961730    454336     447
# 499    50                        타겟  2023    4003424694    424916     986
#
#      screen_number
# id
# 0           188611
# 1           157683
# 2           166218
# 3           133350
# 4           136975
# ..             ...
# 495          27669
# 496          31547
# 497          43356
# 498          14296
# 499          43332
#
# [500 rows x 7 columns]

# %%
genre = pd.read_csv('/home/lim/dev_ws/eda/data/genre_2014_2023.csv')
genre
# Out:
#      Unnamed: 0                      Name  Year  \
# 0            50                        명량  2014
# 1            51                      겨울왕국  2014
# 2            52                     인터스텔라  2014
# 3            53              해적: 바다로 간 산적  2014
# 4            54                    수상한 그녀  2014
# ..          ...                       ...   ...
# 495         545  오늘 밤, 세계에서 이 사랑이 사라진다 해도  2023
# 496         546                    3일의 휴가  2023
# 497         547                       소년들  2023
# 498         548                      타이타닉  2023
# 499         549                        타겟  2023
#
#                                       Genre     Viewers
# 0                              ['사극', '액션']  17,613,682
# 1    ['애니메이션', '어드벤처', '코미디', '뮤지컬', '판타지']  10,296,101
# 2                                    ['SF']  10,105,247
# 3                                  ['어드벤처']   8,666,046
# 4                                   ['드라마']   8,657,982
# ..                                      ...         ...
# 495                              ['멜로/로맨스']     514,915
# 496                          ['판타지', '드라마']     514,541
# 497                           ['드라마', '범죄']     471,425
# 498                 ['드라마', '멜로/로맨스', '액션']     454,336
# 499                                 ['스릴러']     424,916
#
# [500 rows x 5 columns]

# %%
#genre 추가
movie['genre'] = genre['Genre']

movie.head()
# Out:
#     rank          name  year          sale  audience  screen  screen_number  \
# id
# 0      1            명량  2014  135748398910  17613682    1587         188611
# 1      2          겨울왕국  2014   82461504400  10296101    1010         157683
# 2      3         인터스텔라  2014   80671424300  10105247    1410         166218
# 3      4  해적: 바다로 간 산적  2014   66370682706   8666046     910         133350
# 4      5        수상한 그녀  2014   62705348249   8657982    1027         136975
#
#                                      genre
# id
# 0                             ['사극', '액션']
# 1   ['애니메이션', '어드벤처', '코미디', '뮤지컬', '판타지']
# 2                                   ['SF']
# 3                                 ['어드벤처']
# 4                                  ['드라마']

# %%
movie.to_csv("movie_chart.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# #### 1-3. 영화 데이터를 데이터 베이스에 저장

# %%
import mysql.connector
from sqlalchemy import create_engine

df = pd.read_csv('movie_chart.csv')
df.index.name = 'id'


mysql_config = {
    "host": "your aws",
    "port": 3306,
    "user": "your user",
    "password": "12345",
    "database": "your project"
}

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'movie' 
df.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# '\nengine = create_engine(\n    f"mysql+mysqlconnector://{mysql_config[\'user\']}:{mysql_config[\'password\']}@{mysql_config[\'host\']}:{mysql_config[\'port\']}/{mysql_config[\'database\']}"\n)\n\ntable_name = \'movie\' \ndf.to_sql(table_name, con=engine, if_exists=\'replace\', index=True)\n'

# %% [markdown]
# #### 1-4. OTT 전 (2014-2018)

# %%
movie=pd.read_csv('movie_chart.csv')
movie.head()
# Out:
#    rank          name  year          sale  audience  screen  screen_number  \
# 0     1            명량  2014  135748398910  17613682    1587         188611
# 1     2          겨울왕국  2014   82461504400  10296101    1010         157683
# 2     3         인터스텔라  2014   80671424300  10105247    1410         166218
# 3     4  해적: 바다로 간 산적  2014   66370682706   8666046     910         133350
# 4     5        수상한 그녀  2014   62705348249   8657982    1027         136975
#
#                                     genre
# 0                            ['사극', '액션']
# 1  ['애니메이션', '어드벤처', '코미디', '뮤지컬', '판타지']
# 2                                  ['SF']
# 3                                ['어드벤처']
# 4                                 ['드라마']

# %%
movie_before_OTT = movie[movie['year'].between(2014,2018)]
movie_before_OTT.to_csv("movie_before_OTT.csv", index=False, encoding="utf-8-sig")

# %%
movie_before_OTT
# Out:
#      rank          name  year          sale  audience  screen  screen_number  \
# 0       1            명량  2014  135748398910  17613682    1587         188611
# 1       2          겨울왕국  2014   82461504400  10296101    1010         157683
# 2       3         인터스텔라  2014   80671424300  10105247    1410         166218
# 3       4  해적: 바다로 간 산적  2014   66370682706   8666046     910         133350
# 4       5        수상한 그녀  2014   62705348249   8657982    1027         136975
# ..    ...           ...   ...           ...       ...     ...            ...
# 247    48      바람 바람 바람  2018    9784385375   1194229     985          57939
# 248    49     PMC: 더 벙커  2018    9704247367   1179031    1081          26690
# 249    50           범블비  2018    9756083752   1167150    1016          26260
# 284    35          아쿠아맨  2018   13659344323   1546297    1158          50500
# 338    39        위대한 쇼맨  2017    1897251570    306419     598          31915
#
#                                       genre
# 0                              ['사극', '액션']
# 1    ['애니메이션', '어드벤처', '코미디', '뮤지컬', '판타지']
# 2                                    ['SF']
# 3                                  ['어드벤처']
# 4                                   ['드라마']
# ..                                      ...
# 247                                 ['코미디']
# 248                                  ['액션']
# 249                    ['액션', '어드벤처', 'SF']
# 284                                  ['액션']
# 338                          ['드라마', '뮤지컬']
#
# [250 rows x 8 columns]

# %% [markdown]
# #### 1-5. OTT 이후 (2019~2023)

# %%
movie_after_OTT = movie[movie['year'].between(2019,2023)]
movie_after_OTT.to_csv("movie_after_OTT.csv", index=False, encoding="utf-8-sig")

# %%
movie_after_OTT
# Out:
#      rank                      name  year          sale  audience  screen  \
# 250     1                      극한직업  2019  139651845516  16265618    2003
# 251     2                어벤져스: 엔드게임  2019  122181161160  13934399    2835
# 252     3                    겨울왕국 2  2019  111596248720  13369064    2648
# 253     4                       알라딘  2019  106955138359  12552283    1409
# 254     5                       기생충  2019   85883963645  10085275    1948
# ..    ...                       ...   ...           ...       ...     ...
# 495    46  오늘 밤, 세계에서 이 사랑이 사라진다 해도  2022    5198084474    514915     402
# 496    47                    3일의 휴가  2023    4835070689    514541     863
# 497    48                       소년들  2023    4470423586    471425    1042
# 498    49                      타이타닉  2023    6528961730    454336     447
# 499    50                        타겟  2023    4003424694    424916     986
#
#      screen_number                    genre
# 250         292584                  ['코미디']
# 251         241979             ['액션', 'SF']
# 252         282557                ['애니메이션']
# 253         266469          ['어드벤처', '판타지']
# 254         192855                  ['드라마']
# ..             ...                      ...
# 495          27669               ['멜로/로맨스']
# 496          31547           ['판타지', '드라마']
# 497          43356            ['드라마', '범죄']
# 498          14296  ['드라마', '멜로/로맨스', '액션']
# 499          43332                  ['스릴러']
#
# [248 rows x 8 columns]

# %% [markdown]
# ## 2. 문화산업 현황 데이터 정제 + DB 저장
# 저장하기 좋게 세로형으로 변환
#
# https://www.index.go.kr/unity/potal/main/EachDtlPageDetail.do?idx_cd=2752

# %%
media = pd.read_csv('/home/lim/dev_ws/eda/data/media.csv')
media.head()
# Out:
#   Unnamed: 0   2018   2019    2020    2021   2022
# 0        NaN    매출액    매출액     매출액     매출액    매출액
# 1          계  119.6  126.7  128.29  137.51  151.1
# 2         출판   20.9   21.3   21.65    24.7   25.2
# 3         만화    1.2    1.3    1.53    2.13    2.6
# 4         음악    6.1    6.8    6.06    9.37     11

# %%
media.columns = ['type', 2018, 2019, 2020, 2021, 2022] 

# 1. 매출액 칼럼 삭제
media = media[1:]
media.head()
# Out:
#   type   2018   2019    2020    2021   2022
# 1    계  119.6  126.7  128.29  137.51  151.1
# 2   출판   20.9   21.3   21.65    24.7   25.2
# 3   만화    1.2    1.3    1.53    2.13    2.6
# 4   음악    6.1    6.8    6.06    9.37     11
# 5   게임   14.3   15.6   18.89   20.99   22.2

# %%
# 2.  long-form 
media= pd.melt(media, id_vars=['type'], var_name = 'year', value_name='sale' )

# %%
media
# Out:
#       type  year    sale
# 0        계  2018   119.6
# 1       출판  2018    20.9
# 2       만화  2018     1.2
# 3       음악  2018     6.1
# 4       게임  2018    14.3
# 5       영화  2018     5.9
# 6    애니메이션  2018     0.6
# 7   방송(영상)  2018    19.8
# 8       광고  2018    17.2
# 9      캐릭터  2018    12.2
# 10    지식정보  2018    16.3
# 11  콘텐츠솔루션  2018     5.1
# 12       계  2019   126.7
# 13      출판  2019    21.3
# 14      만화  2019     1.3
# 15      음악  2019     6.8
# 16      게임  2019    15.6
# 17      영화  2019     6.4
# 18   애니메이션  2019     0.6
# 19  방송(영상)  2019    20.8
# 20      광고  2019    18.1
# 21     캐릭터  2019    12.6
# 22    지식정보  2019    17.7
# 23  콘텐츠솔루션  2019     5.4
# 24       계  2020  128.29
# 25      출판  2020   21.65
# 26      만화  2020    1.53
# 27      음악  2020    6.06
# 28      게임  2020   18.89
# 29      영화  2020    2.99
# 30   애니메이션  2020    0.55
# 31  방송(영상)  2020   21.96
# 32      광고  2020   17.42
# 33     캐릭터  2020   12.22
# 34    지식정보  2020   19.37
# 35  콘텐츠솔루션  2020    5.64
# 36       계  2021  137.51
# 37      출판  2021    24.7
# 38      만화  2021    2.13
# 39      음악  2021    9.37
# 40      게임  2021   20.99
# 41      영화  2021    3.25
# 42   애니메이션  2021    0.76
# 43  방송(영상)  2021   23.97
# 44      광고  2021   18.92
# 45     캐릭터  2021       5
# 46    지식정보  2021   19.95
# 47  콘텐츠솔루션  2021    8.47
# 48       계  2022   151.1
# 49      출판  2022    25.2
# 50      만화  2022     2.6
# 51      음악  2022      11
# 52      게임  2022    22.2
# 53      영화  2022     7.4
# 54   애니메이션  2022     0.9
# 55  방송(영상)  2022    26.1
# 56      광고  2022    19.7
# 57     캐릭터  2022     5.4
# 58    지식정보  2022    21.5
# 59  콘텐츠솔루션  2022     9.1

# %%
#필요없는 항목 제거 
exclude = ['계', '방송(영상)', '광고', '캐릭터', '지식정보','콘텐츠솔루션']
media = media[~media['type'].isin(exclude)]
media
# Out:
#      type  year   sale
# 1      출판  2018   20.9
# 2      만화  2018    1.2
# 3      음악  2018    6.1
# 4      게임  2018   14.3
# 5      영화  2018    5.9
# 6   애니메이션  2018    0.6
# 13     출판  2019   21.3
# 14     만화  2019    1.3
# 15     음악  2019    6.8
# 16     게임  2019   15.6
# 17     영화  2019    6.4
# 18  애니메이션  2019    0.6
# 25     출판  2020  21.65
# 26     만화  2020   1.53
# 27     음악  2020   6.06
# 28     게임  2020  18.89
# 29     영화  2020   2.99
# 30  애니메이션  2020   0.55
# 37     출판  2021   24.7
# 38     만화  2021   2.13
# 39     음악  2021   9.37
# 40     게임  2021  20.99
# 41     영화  2021   3.25
# 42  애니메이션  2021   0.76
# 49     출판  2022   25.2
# 50     만화  2022    2.6
# 51     음악  2022     11
# 52     게임  2022   22.2
# 53     영화  2022    7.4
# 54  애니메이션  2022    0.9

# %%
media.to_csv("media_data.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# #### 2-1. ID 값 추가하기
# 고유성 유지하기 위해 값을 추가
# 앞에 222이 들어가 세자릿수가 되도록 추가함. (001,002,003...053,054)

# %%
media = pd.read_csv("media_data.csv")
media.head()
# Out:
#   type  year  sale
# 0   출판  2018  20.9
# 1   만화  2018   1.2
# 2   음악  2018   6.1
# 3   게임  2018  14.3
# 4   영화  2018   5.9

# %%
media.loc[:, 'id'] = media.index 
media.loc[:, 'id'] = media['id'].apply(lambda x: f'111{x+1}') 

media
# Out:
# /tmp/ipykernel_6199/3449453502.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1111' '1112' '1113' '1114' '1115' '1116' '1117' '1118' '1119' '11110'
#  '11111' '11112' '11113' '11114' '11115' '11116' '11117' '11118' '11119'
#  '11120' '11121' '11122' '11123' '11124' '11125' '11126' '11127' '11128'
#  '11129' '11130']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   media.loc[:, 'id'] = media['id'].apply(lambda x: f'111{x+1}')
#      type  year   sale     id
# 0      출판  2018  20.90   1111
# 1      만화  2018   1.20   1112
# 2      음악  2018   6.10   1113
# 3      게임  2018  14.30   1114
# 4      영화  2018   5.90   1115
# 5   애니메이션  2018   0.60   1116
# 6      출판  2019  21.30   1117
# 7      만화  2019   1.30   1118
# 8      음악  2019   6.80   1119
# 9      게임  2019  15.60  11110
# 10     영화  2019   6.40  11111
# 11  애니메이션  2019   0.60  11112
# 12     출판  2020  21.65  11113
# 13     만화  2020   1.53  11114
# 14     음악  2020   6.06  11115
# 15     게임  2020  18.89  11116
# 16     영화  2020   2.99  11117
# 17  애니메이션  2020   0.55  11118
# 18     출판  2021  24.70  11119
# 19     만화  2021   2.13  11120
# 20     음악  2021   9.37  11121
# 21     게임  2021  20.99  11122
# 22     영화  2021   3.25  11123
# 23  애니메이션  2021   0.76  11124
# 24     출판  2022  25.20  11125
# 25     만화  2022   2.60  11126
# 26     음악  2022  11.00  11127
# 27     게임  2022  22.20  11128
# 28     영화  2022   7.40  11129
# 29  애니메이션  2022   0.90  11130

# %%
#순서변경
media = media[['id','type','year','sale']]
media
# Out:
#        id   type  year   sale
# 0    1111     출판  2018  20.90
# 1    1112     만화  2018   1.20
# 2    1113     음악  2018   6.10
# 3    1114     게임  2018  14.30
# 4    1115     영화  2018   5.90
# 5    1116  애니메이션  2018   0.60
# 6    1117     출판  2019  21.30
# 7    1118     만화  2019   1.30
# 8    1119     음악  2019   6.80
# 9   11110     게임  2019  15.60
# 10  11111     영화  2019   6.40
# 11  11112  애니메이션  2019   0.60
# 12  11113     출판  2020  21.65
# 13  11114     만화  2020   1.53
# 14  11115     음악  2020   6.06
# 15  11116     게임  2020  18.89
# 16  11117     영화  2020   2.99
# 17  11118  애니메이션  2020   0.55
# 18  11119     출판  2021  24.70
# 19  11120     만화  2021   2.13
# 20  11121     음악  2021   9.37
# 21  11122     게임  2021  20.99
# 22  11123     영화  2021   3.25
# 23  11124  애니메이션  2021   0.76
# 24  11125     출판  2022  25.20
# 25  11126     만화  2022   2.60
# 26  11127     음악  2022  11.00
# 27  11128     게임  2022  22.20
# 28  11129     영화  2022   7.40
# 29  11130  애니메이션  2022   0.90

# %%
media.to_csv("media_data.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# #### 2-2. 매체데이터 DB 저장

# %%
media = pd.read_csv("media_data.csv")

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'media' 
media.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# 30

# %% [markdown]
# ## 3. OTT 데이터 정제 + DB 추가

# %%
ott_sale = pd.read_csv("/home/lim/dev_ws/eda/data/OTT_sale.csv")

ott_sale.head()
# Out:
#            name Unnamed: 1    2019  2020  2021  2022  2023
# 0       netflix       sale  1859.0  4154  6317  7733  8233
# 1          wave       sale   973.0  1802  2301  2735  2480
# 2        tiving       sale     NaN   155  1315  2476  3264
# 3        watcha       sale   217.0   377   663   592   430
# 4  Google korea       sale  2124.0  2201  2924  3449  3653

# %%
ott_sale.columns = ['name', 'sale',2019, 2020, 2021, 2022, 2023] 
ott_sale.head()
# Out:
#            name  sale    2019  2020  2021  2022  2023
# 0       netflix  sale  1859.0  4154  6317  7733  8233
# 1          wave  sale   973.0  1802  2301  2735  2480
# 2        tiving  sale     NaN   155  1315  2476  3264
# 3        watcha  sale   217.0   377   663   592   430
# 4  Google korea  sale  2124.0  2201  2924  3449  3653

# %%
exclude = ['tiving']
ott_sale = ott_sale[~ott_sale['name'].isin(exclude)]
ott_sale = ott_sale.drop('sale', axis=1)
ott_sale
# Out:
#            name    2019  2020  2021  2022  2023
# 0       netflix  1859.0  4154  6317  7733  8233
# 1          wave   973.0  1802  2301  2735  2480
# 3        watcha   217.0   377   663   592   430
# 4  Google korea  2124.0  2201  2924  3449  3653

# %%
# long-form 
ott_sale= pd.melt(ott_sale, id_vars=['name'], var_name = 'year', value_name='sale' )
ott_sale.head()
# Out:
#            name  year    sale
# 0       netflix  2019  1859.0
# 1          wave  2019   973.0
# 2        watcha  2019   217.0
# 3  Google korea  2019  2124.0
# 4       netflix  2020  4154.0

# %% [markdown]
# ### 3-1. ID 추가
# 2221, 2222.... 이런식

# %%
ott_sale.loc[:, 'id'] = ott_sale.index 
ott_sale.loc[:, 'id'] = ott_sale['id'].apply(lambda x: f'222{x+1}') 

ott_sale
# Out:
# /tmp/ipykernel_6199/3310577559.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['2221' '2222' '2223' '2224' '2225' '2226' '2227' '2228' '2229' '22210'
#  '22211' '22212' '22213' '22214' '22215' '22216' '22217' '22218' '22219'
#  '22220']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   ott_sale.loc[:, 'id'] = ott_sale['id'].apply(lambda x: f'222{x+1}')
#             name  year    sale     id
# 0        netflix  2019  1859.0   2221
# 1           wave  2019   973.0   2222
# 2         watcha  2019   217.0   2223
# 3   Google korea  2019  2124.0   2224
# 4        netflix  2020  4154.0   2225
# 5           wave  2020  1802.0   2226
# 6         watcha  2020   377.0   2227
# 7   Google korea  2020  2201.0   2228
# 8        netflix  2021  6317.0   2229
# 9           wave  2021  2301.0  22210
# 10        watcha  2021   663.0  22211
# 11  Google korea  2021  2924.0  22212
# 12       netflix  2022  7733.0  22213
# 13          wave  2022  2735.0  22214
# 14        watcha  2022   592.0  22215
# 15  Google korea  2022  3449.0  22216
# 16       netflix  2023  8233.0  22217
# 17          wave  2023  2480.0  22218
# 18        watcha  2023   430.0  22219
# 19  Google korea  2023  3653.0  22220

# %%
ott_sale.to_csv("ott_sale.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## 4. OTT_TAKE -매출이익 정리

# %%
ott_take = pd.read_csv("/home/lim/dev_ws/eda/data/OTT_take.csv")
ott_take.head()
# Out:
#            name  2019  2020  2021  2022  2023
# 0       netflix    22    88   171   143   121
# 1          wave  -137  -169  -558 -1213  -791
# 2        watcha   -92  -126  -197  -454  -221
# 3  Google korea   102   156   294   278   234

# %%
ott_take.columns = ['name',2019, 2020, 2021, 2022, 2023] 
ott_take.head()
# Out:
#            name  2019  2020  2021  2022  2023
# 0       netflix    22    88   171   143   121
# 1          wave  -137  -169  -558 -1213  -791
# 2        watcha   -92  -126  -197  -454  -221
# 3  Google korea   102   156   294   278   234

# %%
# long-form 
ott_take= pd.melt(ott_take, id_vars=['name'], var_name = 'year', value_name='take' )
ott_take.head()
# Out:
#            name  year  take
# 0       netflix  2019    22
# 1          wave  2019  -137
# 2        watcha  2019   -92
# 3  Google korea  2019   102
# 4       netflix  2020    88

# %% [markdown]
# ### 3-1. 두 데이터 합쳐주기

# %%
#take 추가
ott_sale['take'] = ott_take['take']

ott_sale.head()
# Out:
#            name  year    sale    id  take
# 0       netflix  2019  1859.0  2221    22
# 1          wave  2019   973.0  2222  -137
# 2        watcha  2019   217.0  2223   -92
# 3  Google korea  2019  2124.0  2224   102
# 4       netflix  2020  4154.0  2225    88

# %%
ott_sale = ott_sale[['id','name','year','sale', 'take']]
ott_sale
# Out:
#        id          name  year    sale  take
# 0    2221       netflix  2019  1859.0    22
# 1    2222          wave  2019   973.0  -137
# 2    2223        watcha  2019   217.0   -92
# 3    2224  Google korea  2019  2124.0   102
# 4    2225       netflix  2020  4154.0    88
# 5    2226          wave  2020  1802.0  -169
# 6    2227        watcha  2020   377.0  -126
# 7    2228  Google korea  2020  2201.0   156
# 8    2229       netflix  2021  6317.0   171
# 9   22210          wave  2021  2301.0  -558
# 10  22211        watcha  2021   663.0  -197
# 11  22212  Google korea  2021  2924.0   294
# 12  22213       netflix  2022  7733.0   143
# 13  22214          wave  2022  2735.0 -1213
# 14  22215        watcha  2022   592.0  -454
# 15  22216  Google korea  2022  3449.0   278
# 16  22217       netflix  2023  8233.0   121
# 17  22218          wave  2023  2480.0  -791
# 18  22219        watcha  2023   430.0  -221
# 19  22220  Google korea  2023  3653.0   234

# %%
ott_sale.to_csv("ott.csv", index=False, encoding="utf-8-sig")

# %%
ott = pd.read_csv("ott.csv")

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'ott' 
ott.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# 20

# %% [markdown]
# ## 4. 스크린 데이터 정제 + DB 추가

# %%
#2014-2018
screenA = pd.read_csv('/home/lim/dev_ws/eda/data/movie(2014~2018).csv')
screenA.head()
# Out:
#   영화 제목      상영타입   스크린수     상영횟수              누적매출액(점유율)         누적관객수(점유율)
# 0    명량        필름      1        5           133,000(0.0%)           17(0.0%)
# 1    명량       디지털  2,145  187,193  135,269,836,010(99.6%)  17,552,919(99.6%)
# 2    명량  디지털 영문자막     30       85        40,515,300(0.0%)        5,068(0.0%)
# 3    명량        4D     20    1,379       428,484,000(0.3%)       52,742(0.3%)
# 4    명량   디지털 가치봄     48       68        23,547,000(0.0%)        5,625(0.0%)

# %%
#2019-2023
screenB = pd.read_csv('/home/lim/dev_ws/eda/data/movie(2019~2023).csv')
screenB.head()
# Out:
#         영화 제목      상영타입   스크린수     상영횟수               누적매출액(점유율)  \
# 0        극한직업       디지털  2,853  292,735  139,639,103,516(100.0%)
# 1        극한직업  디지털 영문자막      1        1              6,000(0.0%)
# 2        극한직업   디지털 가치봄     61       82         18,050,000(0.0%)
# 3  어벤져스: 엔드게임       디지털  2,910  232,605   106,300,879,170(86.8%)
# 4  어벤져스: 엔드게임        4D     50    6,819      3,983,260,500(3.3%)
#
#            누적관객수(점유율)
# 0  16,262,992(100.0%)
# 1             1(0.0%)
# 2         3,493(0.0%)
# 3   12,773,929(91.4%)
# 4       380,194(2.7%)

# %%
screen = pd.concat([screenA,screenB], ignore_index = True)

# %%
screen
# Out:
#      영화 제목            상영타입   스크린수     상영횟수              누적매출액(점유율)  \
# 0       명량              필름      1        5           133,000(0.0%)
# 1       명량             디지털  2,145  187,193  135,269,836,010(99.6%)
# 2       명량        디지털 영문자막     30       85        40,515,300(0.0%)
# 3       명량              4D     20    1,379       428,484,000(0.3%)
# 4       명량         디지털 가치봄     48       68        23,547,000(0.0%)
# ...    ...             ...    ...      ...                     ...
# 1539  타이타닉              4D     12    1,207       889,682,000(7.8%)
# 1540  타이타닉          3D 디지털    846   22,427    8,429,304,840(73.7%)
# 1541  타이타닉         IMAX 3D     24      910    1,492,293,000(13.1%)
# 1542  타이타닉  DOLBYCINEMA 3D      5      114       186,054,390(1.6%)
# 1543    타겟             디지털  2,344   43,332   4,003,424,694(100.0%)
#
#              누적관객수(점유율)
# 0              17(0.0%)
# 1     17,552,919(99.6%)
# 2           5,068(0.0%)
# 3          52,742(0.3%)
# 4           5,625(0.0%)
# ...                 ...
# 1539       75,429(8.5%)
# 1540     654,868(74.1%)
# 1541       83,245(9.4%)
# 1542        9,998(1.1%)
# 1543    424,916(100.0%)
#
# [1544 rows x 6 columns]

# %%
screen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1544 entries, 0 to 1543
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   영화 제목       1544 non-null   object
#  1   상영타입        1544 non-null   object
#  2   스크린수        1544 non-null   object
#  3   상영횟수        1544 non-null   object
#  4   누적매출액(점유율)  1544 non-null   object
#  5   누적관객수(점유율)  1544 non-null   object
# dtypes: object(6)
# memory usage: 72.5+ KB

# %%
#칼럼명 다듬기 
screen.columns = ['name', 'screen_type', 'screen', 'screening', 'sale', 'audience']

# %%
screen.head()
# Out:
#   name screen_type screen screening                    sale           audience
# 0   명량          필름      1         5           133,000(0.0%)           17(0.0%)
# 1   명량         디지털  2,145   187,193  135,269,836,010(99.6%)  17,552,919(99.6%)
# 2   명량    디지털 영문자막     30        85        40,515,300(0.0%)        5,068(0.0%)
# 3   명량          4D     20     1,379       428,484,000(0.3%)       52,742(0.3%)
# 4   명량     디지털 가치봄     48        68        23,547,000(0.0%)        5,625(0.0%)

# %%
# , 제거 
screen['screen'] = screen.screen.str.replace(',','')
screen['screening'] = screen.screening.str.replace(',','')
screen['sale'] = screen.sale.str.replace(',','')
screen['audience'] = screen.audience.str.replace(',','')

screen.head()
# Out:
#   name screen_type screen screening                 sale         audience
# 0   명량          필름      1         5         133000(0.0%)         17(0.0%)
# 1   명량         디지털   2145    187193  135269836010(99.6%)  17552919(99.6%)
# 2   명량    디지털 영문자막     30        85       40515300(0.0%)       5068(0.0%)
# 3   명량          4D     20      1379      428484000(0.3%)      52742(0.3%)
# 4   명량     디지털 가치봄     48        68       23547000(0.0%)       5625(0.0%)

# %%
#(n.n%) 제거 
screen['sale'] = screen['sale'].str.replace(r'\(.*?\)', '', regex=True).str.strip()
screen['audience'] = screen['audience'].str.replace(r'\(.*?\)', '', regex=True).str.strip()

screen.head()
# Out:
#   name screen_type screen screening          sale  audience
# 0   명량          필름      1         5        133000        17
# 1   명량         디지털   2145    187193  135269836010  17552919
# 2   명량    디지털 영문자막     30        85      40515300      5068
# 3   명량          4D     20      1379     428484000     52742
# 4   명량     디지털 가치봄     48        68      23547000      5625

# %%
#데이터 타입 바꾸기 
screen=screen.astype(dtype={
                          'screen':'int',
                          'screening':'int',
                          'sale':'int',
                          'audience':'int'
                          })

screen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1544 entries, 0 to 1543
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1544 non-null   object
#  1   screen_type  1544 non-null   object
#  2   screen       1544 non-null   int64
#  3   screening    1544 non-null   int64
#  4   sale         1544 non-null   int64
#  5   audience     1544 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 72.5+ KB

# %%
screen.to_csv("screen.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### 4-1. year 데이터 추가

# %%
#년도 데이터를 추가하기 위해 이전에 사용한 데이터 불러옴
year_add_data = pd.read_csv('/home/lim/dev_ws/eda/data/movie_genre_data.csv')
year_add_data.head()
# Out:
#    Unnamed: 0     Name  Year                 Genre     Viewers
# 0           0  7번방의 선물  2013        ['코미디', '드라마']  12,811,206
# 1           1     설국열차  2013          ['SF', '액션']   9,349,993
# 2           2       관상  2013         ['사극', '드라마']   9,134,238
# 3           3   아이언맨 3  2013  ['액션', '어드벤처', 'SF']   9,001,331
# 4           4      베를린  2013                ['액션']   7,166,290

# %%
year_add_data = year_add_data[year_add_data['Year'].between(2014,2023)]

year_add_data
# Out:
#      Unnamed: 0                      Name  Year  \
# 50           50                        명량  2014
# 51           51                      겨울왕국  2014
# 52           52                     인터스텔라  2014
# 53           53              해적: 바다로 간 산적  2014
# 54           54                    수상한 그녀  2014
# ..          ...                       ...   ...
# 545         545  오늘 밤, 세계에서 이 사랑이 사라진다 해도  2023
# 546         546                    3일의 휴가  2023
# 547         547                       소년들  2023
# 548         548                      타이타닉  2023
# 549         549                        타겟  2023
#
#                                       Genre     Viewers
# 50                             ['사극', '액션']  17,613,682
# 51   ['애니메이션', '어드벤처', '코미디', '뮤지컬', '판타지']  10,296,101
# 52                                   ['SF']  10,105,247
# 53                                 ['어드벤처']   8,666,046
# 54                                  ['드라마']   8,657,982
# ..                                      ...         ...
# 545                              ['멜로/로맨스']     514,915
# 546                          ['판타지', '드라마']     514,541
# 547                           ['드라마', '범죄']     471,425
# 548                 ['드라마', '멜로/로맨스', '액션']     454,336
# 549                                 ['스릴러']     424,916
#
# [500 rows x 5 columns]

# %%
screen_data = screen.merge(year_add_data[['Name', 'Year']], left_on='name', right_on='Name', how='left')
screen_data.drop(columns=['Name'], inplace=True)

screen_data
# Out:
#       name     screen_type  screen  screening          sale  audience  Year
# 0       명량              필름       1          5        133000        17  2014
# 1       명량             디지털    2145     187193  135269836010  17552919  2014
# 2       명량        디지털 영문자막      30         85      40515300      5068  2014
# 3       명량              4D      20       1379     428484000     52742  2014
# 4       명량         디지털 가치봄      48         68      23547000      5625  2014
# ...    ...             ...     ...        ...           ...       ...   ...
# 1675  타이타닉              4D      12       1207     889682000     75429  2023
# 1676  타이타닉          3D 디지털     846      22427    8429304840    654868  2023
# 1677  타이타닉         IMAX 3D      24        910    1492293000     83245  2023
# 1678  타이타닉  DOLBYCINEMA 3D       5        114     186054390      9998  2023
# 1679    타겟             디지털    2344      43332    4003424694    424916  2023
#
# [1680 rows x 7 columns]

# %% [markdown]
# ### 4-2. ID 추가
# 3331,3332...

# %%
screen_data.loc[:, 'id'] = screen_data.index 
screen_data.loc[:, 'id'] = screen_data['id'].apply(lambda x: f'333{x+1}') 

screen_data
# Out:
# /tmp/ipykernel_18544/3440455508.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['3331' '3332' '3333' ... '3331678' '3331679' '3331680']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   screen_data.loc[:, 'id'] = screen_data['id'].apply(lambda x: f'333{x+1}')
#       name     screen_type  screen  screening          sale  audience  Year  \
# 0       명량              필름       1          5        133000        17  2014
# 1       명량             디지털    2145     187193  135269836010  17552919  2014
# 2       명량        디지털 영문자막      30         85      40515300      5068  2014
# 3       명량              4D      20       1379     428484000     52742  2014
# 4       명량         디지털 가치봄      48         68      23547000      5625  2014
# ...    ...             ...     ...        ...           ...       ...   ...
# 1675  타이타닉              4D      12       1207     889682000     75429  2023
# 1676  타이타닉          3D 디지털     846      22427    8429304840    654868  2023
# 1677  타이타닉         IMAX 3D      24        910    1492293000     83245  2023
# 1678  타이타닉  DOLBYCINEMA 3D       5        114     186054390      9998  2023
# 1679    타겟             디지털    2344      43332    4003424694    424916  2023
#
#            id
# 0        3331
# 1        3332
# 2        3333
# 3        3334
# 4        3335
# ...       ...
# 1675  3331676
# 1676  3331677
# 1677  3331678
# 1678  3331679
# 1679  3331680
#
# [1680 rows x 8 columns]

# %%
screen_data = screen_data[['id','name', 'Year', 'screen_type', 'screening', 'sale', 'audience']]

# %%
screen_data
# Out:
#            id  name  Year     screen_type  screening          sale  audience
# 0        3331    명량  2014              필름          5        133000        17
# 1        3332    명량  2014             디지털     187193  135269836010  17552919
# 2        3333    명량  2014        디지털 영문자막         85      40515300      5068
# 3        3334    명량  2014              4D       1379     428484000     52742
# 4        3335    명량  2014         디지털 가치봄         68      23547000      5625
# ...       ...   ...   ...             ...        ...           ...       ...
# 1675  3331676  타이타닉  2023              4D       1207     889682000     75429
# 1676  3331677  타이타닉  2023          3D 디지털      22427    8429304840    654868
# 1677  3331678  타이타닉  2023         IMAX 3D        910    1492293000     83245
# 1678  3331679  타이타닉  2023  DOLBYCINEMA 3D        114     186054390      9998
# 1679  3331680    타겟  2023             디지털      43332    4003424694    424916
#
# [1680 rows x 7 columns]

# %%
screen_data.to_csv("screen.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### 4-3. DB 추가

# %%
screen_data= pd.read_csv("screen.csv")

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'screen' 
screen_data.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# 1680

# %% [markdown]
# ## 5. 공연 티켓 판매량 정제 + DB 저장

# %%
performance_data = pd.read_csv("/home/lim/dev_ws/eda/data/performance_data.csv")
performance_data
# Out:
#    year         sale
# 0  2020   236320.200
# 1  2021   391433.300
# 2  2022   996243.800
# 3  2023  1310570.868

# %% [markdown]
# ### 5-1. ID  추가
# 444

# %%
performance_data.loc[:, 'id'] = performance_data.index 
performance_data.loc[:, 'id'] = performance_data['id'].apply(lambda x: f'444{x+1}') 
performance_data
# Out:
# /tmp/ipykernel_18544/2742031035.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['4441' '4442' '4443' '4444']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   performance_data.loc[:, 'id'] = performance_data['id'].apply(lambda x: f'444{x+1}')
#    year         sale    id
# 0  2020   236320.200  4441
# 1  2021   391433.300  4442
# 2  2022   996243.800  4443
# 3  2023  1310570.868  4444

# %%
performance_data = performance_data[['id', 'year', 'sale']]
performance_data
# Out:
#      id  year         sale
# 0  4441  2020   236320.200
# 1  4442  2021   391433.300
# 2  4443  2022   996243.800
# 3  4444  2023  1310570.868

# %%
performance_data.to_csv("performance.csv", index=False, encoding="utf-8-sig")

# %%
performance_data= pd.read_csv("performance.csv")

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'performance' 
performance_data.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# 4

# %% [markdown]
# ## 6. netflix, TIVING top 20(2025년 1월 2일 기준)

# %% [markdown]
# ### 6-1. netflix

# %%
netflix = pd.read_csv('netflix.csv')
netflix
# Out:
#     rank             name                                  genre  score
# 0      1      오징어 게임 시즌 2                 드라마, 스릴러, 서스펜스, 공포(호러)   78.6
# 1      2            옥씨부인전                                    드라마   83.6
# 2      3        지금 거신 전화는                            멜로/로맨스, 스릴러   85.9
# 3      4           체크인 한양                            드라마, 멜로/로맨스   80.0
# 4      5  나는 SOLO <나는 솔로>                                     예능   79.4
# 5      6          퍼펙트 데이즈                                    드라마   98.0
# 6      7              파일럿                                    코미디   68.8
# 7      8     이혼숙려캠프: 새로고침                                     예능   45.5
# 8      9              캐리온                          액션, 스릴러, 미스터리   90.7
# 9     10            베테랑 2                                 액션, 범죄   78.8
# 10    11            수퍼 소닉  애니메이션, 액션, 어드벤처(모험), 코미디, 가족, 판타지, SF   68.2
# 11    12          사랑의 하츄핑                                  애니메이션   88.6
# 12    13     더 킬러: 죽음의 여왕                            액션, 스릴러, 범죄   57.1
# 13    14               파묘                      스릴러, 공포(호러), 미스터리   91.8
# 14    15          미스터트롯 3                                 예능, 음악    NaN
# 15    16              트렁크                         로맨스, 미스터리, 드라마   61.6
# 16    17         대도시의 사랑법                               드라마, 로맨스   86.3
# 17    18          그녀가 죽었다                              미스터리, 스릴러   82.9
# 18    19               화란                                드라마, 범죄   77.4
# 19    20               탈주                                     액션   80.3

# %%
#칼럼명 다듬기 
netflix.columns = ['rnk', 'name', 'genre', 'score']
netflix
# Out:
#     rnk             name                                  genre  score
# 0     1      오징어 게임 시즌 2                 드라마, 스릴러, 서스펜스, 공포(호러)   78.6
# 1     2            옥씨부인전                                    드라마   83.6
# 2     3        지금 거신 전화는                            멜로/로맨스, 스릴러   85.9
# 3     4           체크인 한양                            드라마, 멜로/로맨스   80.0
# 4     5  나는 SOLO <나는 솔로>                                     예능   79.4
# 5     6          퍼펙트 데이즈                                    드라마   98.0
# 6     7              파일럿                                    코미디   68.8
# 7     8     이혼숙려캠프: 새로고침                                     예능   45.5
# 8     9              캐리온                          액션, 스릴러, 미스터리   90.7
# 9    10            베테랑 2                                 액션, 범죄   78.8
# 10   11            수퍼 소닉  애니메이션, 액션, 어드벤처(모험), 코미디, 가족, 판타지, SF   68.2
# 11   12          사랑의 하츄핑                                  애니메이션   88.6
# 12   13     더 킬러: 죽음의 여왕                            액션, 스릴러, 범죄   57.1
# 13   14               파묘                      스릴러, 공포(호러), 미스터리   91.8
# 14   15          미스터트롯 3                                 예능, 음악    NaN
# 15   16              트렁크                         로맨스, 미스터리, 드라마   61.6
# 16   17         대도시의 사랑법                               드라마, 로맨스   86.3
# 17   18          그녀가 죽었다                              미스터리, 스릴러   82.9
# 18   19               화란                                드라마, 범죄   77.4
# 19   20               탈주                                     액션   80.3

# %% [markdown]
# #### 6-1-1. netflix ID 추가
# 5551,5552...

# %%
netflix.loc[:, 'id'] = netflix.index 
netflix.loc[:, 'id'] = netflix['id'].apply(lambda x: f'555{x+1}') 
netflix
# Out:
# /tmp/ipykernel_21199/891156662.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['5551' '5552' '5553' '5554' '5555' '5556' '5557' '5558' '5559' '55510'
#  '55511' '55512' '55513' '55514' '55515' '55516' '55517' '55518' '55519'
#  '55520']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   netflix.loc[:, 'id'] = netflix['id'].apply(lambda x: f'555{x+1}')
#     rnk             name                                  genre  score     id
# 0     1      오징어 게임 시즌 2                 드라마, 스릴러, 서스펜스, 공포(호러)   78.6   5551
# 1     2            옥씨부인전                                    드라마   83.6   5552
# 2     3        지금 거신 전화는                            멜로/로맨스, 스릴러   85.9   5553
# 3     4           체크인 한양                            드라마, 멜로/로맨스   80.0   5554
# 4     5  나는 SOLO <나는 솔로>                                     예능   79.4   5555
# 5     6          퍼펙트 데이즈                                    드라마   98.0   5556
# 6     7              파일럿                                    코미디   68.8   5557
# 7     8     이혼숙려캠프: 새로고침                                     예능   45.5   5558
# 8     9              캐리온                          액션, 스릴러, 미스터리   90.7   5559
# 9    10            베테랑 2                                 액션, 범죄   78.8  55510
# 10   11            수퍼 소닉  애니메이션, 액션, 어드벤처(모험), 코미디, 가족, 판타지, SF   68.2  55511
# 11   12          사랑의 하츄핑                                  애니메이션   88.6  55512
# 12   13     더 킬러: 죽음의 여왕                            액션, 스릴러, 범죄   57.1  55513
# 13   14               파묘                      스릴러, 공포(호러), 미스터리   91.8  55514
# 14   15          미스터트롯 3                                 예능, 음악    NaN  55515
# 15   16              트렁크                         로맨스, 미스터리, 드라마   61.6  55516
# 16   17         대도시의 사랑법                               드라마, 로맨스   86.3  55517
# 17   18          그녀가 죽었다                              미스터리, 스릴러   82.9  55518
# 18   19               화란                                드라마, 범죄   77.4  55519
# 19   20               탈주                                     액션   80.3  55520

# %%
netflix = netflix[['id','rnk', 'name', 'genre', 'score']]
netflix
# Out:
#        id  rnk             name                                  genre  score
# 0    5551    1      오징어 게임 시즌 2                 드라마, 스릴러, 서스펜스, 공포(호러)   78.6
# 1    5552    2            옥씨부인전                                    드라마   83.6
# 2    5553    3        지금 거신 전화는                            멜로/로맨스, 스릴러   85.9
# 3    5554    4           체크인 한양                            드라마, 멜로/로맨스   80.0
# 4    5555    5  나는 SOLO <나는 솔로>                                     예능   79.4
# 5    5556    6          퍼펙트 데이즈                                    드라마   98.0
# 6    5557    7              파일럿                                    코미디   68.8
# 7    5558    8     이혼숙려캠프: 새로고침                                     예능   45.5
# 8    5559    9              캐리온                          액션, 스릴러, 미스터리   90.7
# 9   55510   10            베테랑 2                                 액션, 범죄   78.8
# 10  55511   11            수퍼 소닉  애니메이션, 액션, 어드벤처(모험), 코미디, 가족, 판타지, SF   68.2
# 11  55512   12          사랑의 하츄핑                                  애니메이션   88.6
# 12  55513   13     더 킬러: 죽음의 여왕                            액션, 스릴러, 범죄   57.1
# 13  55514   14               파묘                      스릴러, 공포(호러), 미스터리   91.8
# 14  55515   15          미스터트롯 3                                 예능, 음악    NaN
# 15  55516   16              트렁크                         로맨스, 미스터리, 드라마   61.6
# 16  55517   17         대도시의 사랑법                               드라마, 로맨스   86.3
# 17  55518   18          그녀가 죽었다                              미스터리, 스릴러   82.9
# 18  55519   19               화란                                드라마, 범죄   77.4
# 19  55520   20               탈주                                     액션   80.3

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20 non-null     object
#  1   rnk     20 non-null     int64
#  2   name    20 non-null     object
#  3   genre   20 non-null     object
#  4   score   19 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 928.0+ bytes

# %%
netflix=netflix.astype(dtype={
                          'id':'int',
                          'rnk':'int',
                          'score':'float',
                          })

netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20 non-null     int64
#  1   rnk     20 non-null     int64
#  2   name    20 non-null     object
#  3   genre   20 non-null     object
#  4   score   19 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 928.0+ bytes

# %%
netflix.to_csv("netflix.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# #### 6-1-2. netflix 저장

# %%
netflix = pd.read_csv("netflix.csv")

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'netflix' 
netflix.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# 20

# %% [markdown]
# ### 6-2. tiving

# %%
tiving = pd.read_csv('tiving.csv')
tiving
# Out:
#     rank                 name                        genre  score
# 0      1                옥씨부인전                          드라마   83.6
# 1      2               체크인 한양                     드라마, 로맨스   80.0
# 2      3        해리 포터와 마법사의 돌            판타지, 가족, 어드벤처(모험)   96.8
# 3      4           더 퍼스트 슬램덩크                   애니메이션, 드라마   97.6
# 4      5      나는 SOLO <나는 솔로>                           예능   79.4
# 5      6          해리 포터와 불의 잔  판타지, 가족, 액션, 어드벤처(모험), 미스터리   94.5
# 6      7         이혼숙려캠프: 새로고침                           예능   45.5
# 7      8           존 오브 인터레스트                      드라마, 전쟁   95.4
# 8      9        더러운 돈에 손대지 마라                      범죄, 드라마   36.0
# 9     10         해리 포터와 비밀의 방      판타지, 가족, 어드벤처(모험), 미스터리   96.8
# 10    11       해리 포터와 불사조 기사단  판타지, 액션, 어드벤처(모험), 가족, 미스터리   91.4
# 11    12      해리 포터와 아즈카반의 죄수            판타지, 가족, 어드벤처(모험)   96.7
# 12    13                  류주기       액션, 어드벤처(모험), 드라마, 로맨스    NaN
# 13    14                   파묘            스릴러, 공포(호러), 미스터리   91.8
# 14    15              미스터트롯 3                       예능, 음악    NaN
# 15    16             대도시의 사랑법                     드라마, 로맨스   86.3
# 16    17          사랑은 외나무다리에서                  멜로/로맨스, 코미디   85.7
# 17    18  냉장고를 부탁해 since 2014                           예능   92.6
# 18    19         해리 포터와 혼혈 왕자          판타지, 어드벤처(모험), 미스터리   89.2
# 19    20                   남남                      드라마, 가족   96.8

# %%
#칼럼명 다듬기 
tiving.columns = ['rnk', 'name', 'genre', 'score']
tiving
# Out:
#     rnk                 name                        genre  score
# 0     1                옥씨부인전                          드라마   83.6
# 1     2               체크인 한양                     드라마, 로맨스   80.0
# 2     3        해리 포터와 마법사의 돌            판타지, 가족, 어드벤처(모험)   96.8
# 3     4           더 퍼스트 슬램덩크                   애니메이션, 드라마   97.6
# 4     5      나는 SOLO <나는 솔로>                           예능   79.4
# 5     6          해리 포터와 불의 잔  판타지, 가족, 액션, 어드벤처(모험), 미스터리   94.5
# 6     7         이혼숙려캠프: 새로고침                           예능   45.5
# 7     8           존 오브 인터레스트                      드라마, 전쟁   95.4
# 8     9        더러운 돈에 손대지 마라                      범죄, 드라마   36.0
# 9    10         해리 포터와 비밀의 방      판타지, 가족, 어드벤처(모험), 미스터리   96.8
# 10   11       해리 포터와 불사조 기사단  판타지, 액션, 어드벤처(모험), 가족, 미스터리   91.4
# 11   12      해리 포터와 아즈카반의 죄수            판타지, 가족, 어드벤처(모험)   96.7
# 12   13                  류주기       액션, 어드벤처(모험), 드라마, 로맨스    NaN
# 13   14                   파묘            스릴러, 공포(호러), 미스터리   91.8
# 14   15              미스터트롯 3                       예능, 음악    NaN
# 15   16             대도시의 사랑법                     드라마, 로맨스   86.3
# 16   17          사랑은 외나무다리에서                  멜로/로맨스, 코미디   85.7
# 17   18  냉장고를 부탁해 since 2014                           예능   92.6
# 18   19         해리 포터와 혼혈 왕자          판타지, 어드벤처(모험), 미스터리   89.2
# 19   20                   남남                      드라마, 가족   96.8

# %% [markdown]
# #### 6-2-1. ID 추가
# 6661,6662

# %%
tiving.loc[:, 'id'] = tiving.index 
tiving.loc[:, 'id'] = tiving['id'].apply(lambda x: f'666{x+1}') 
tiving
# Out:
# /tmp/ipykernel_21199/3235824116.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['6661' '6662' '6663' '6664' '6665' '6666' '6667' '6668' '6669' '66610'
#  '66611' '66612' '66613' '66614' '66615' '66616' '66617' '66618' '66619'
#  '66620']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tiving.loc[:, 'id'] = tiving['id'].apply(lambda x: f'666{x+1}')
#     rnk                 name                        genre  score     id
# 0     1                옥씨부인전                          드라마   83.6   6661
# 1     2               체크인 한양                     드라마, 로맨스   80.0   6662
# 2     3        해리 포터와 마법사의 돌            판타지, 가족, 어드벤처(모험)   96.8   6663
# 3     4           더 퍼스트 슬램덩크                   애니메이션, 드라마   97.6   6664
# 4     5      나는 SOLO <나는 솔로>                           예능   79.4   6665
# 5     6          해리 포터와 불의 잔  판타지, 가족, 액션, 어드벤처(모험), 미스터리   94.5   6666
# 6     7         이혼숙려캠프: 새로고침                           예능   45.5   6667
# 7     8           존 오브 인터레스트                      드라마, 전쟁   95.4   6668
# 8     9        더러운 돈에 손대지 마라                      범죄, 드라마   36.0   6669
# 9    10         해리 포터와 비밀의 방      판타지, 가족, 어드벤처(모험), 미스터리   96.8  66610
# 10   11       해리 포터와 불사조 기사단  판타지, 액션, 어드벤처(모험), 가족, 미스터리   91.4  66611
# 11   12      해리 포터와 아즈카반의 죄수            판타지, 가족, 어드벤처(모험)   96.7  66612
# 12   13                  류주기       액션, 어드벤처(모험), 드라마, 로맨스    NaN  66613
# 13   14                   파묘            스릴러, 공포(호러), 미스터리   91.8  66614
# 14   15              미스터트롯 3                       예능, 음악    NaN  66615
# 15   16             대도시의 사랑법                     드라마, 로맨스   86.3  66616
# 16   17          사랑은 외나무다리에서                  멜로/로맨스, 코미디   85.7  66617
# 17   18  냉장고를 부탁해 since 2014                           예능   92.6  66618
# 18   19         해리 포터와 혼혈 왕자          판타지, 어드벤처(모험), 미스터리   89.2  66619
# 19   20                   남남                      드라마, 가족   96.8  66620

# %%
tiving = netflix[['id','rnk', 'name', 'genre', 'score']]
tiving
# Out:
#        id  rnk             name                                  genre  score
# 0    5551    1      오징어 게임 시즌 2                 드라마, 스릴러, 서스펜스, 공포(호러)   78.6
# 1    5552    2            옥씨부인전                                    드라마   83.6
# 2    5553    3        지금 거신 전화는                            멜로/로맨스, 스릴러   85.9
# 3    5554    4           체크인 한양                            드라마, 멜로/로맨스   80.0
# 4    5555    5  나는 SOLO <나는 솔로>                                     예능   79.4
# 5    5556    6          퍼펙트 데이즈                                    드라마   98.0
# 6    5557    7              파일럿                                    코미디   68.8
# 7    5558    8     이혼숙려캠프: 새로고침                                     예능   45.5
# 8    5559    9              캐리온                          액션, 스릴러, 미스터리   90.7
# 9   55510   10            베테랑 2                                 액션, 범죄   78.8
# 10  55511   11            수퍼 소닉  애니메이션, 액션, 어드벤처(모험), 코미디, 가족, 판타지, SF   68.2
# 11  55512   12          사랑의 하츄핑                                  애니메이션   88.6
# 12  55513   13     더 킬러: 죽음의 여왕                            액션, 스릴러, 범죄   57.1
# 13  55514   14               파묘                      스릴러, 공포(호러), 미스터리   91.8
# 14  55515   15          미스터트롯 3                                 예능, 음악    NaN
# 15  55516   16              트렁크                         로맨스, 미스터리, 드라마   61.6
# 16  55517   17         대도시의 사랑법                               드라마, 로맨스   86.3
# 17  55518   18          그녀가 죽었다                              미스터리, 스릴러   82.9
# 18  55519   19               화란                                드라마, 범죄   77.4
# 19  55520   20               탈주                                     액션   80.3

# %%
tiving.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20 non-null     int64
#  1   rnk     20 non-null     int64
#  2   name    20 non-null     object
#  3   genre   20 non-null     object
#  4   score   19 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 928.0+ bytes

# %% [markdown]
# #### 6-2-2. tiving DB 추가

# %%
tiving= pd.read_csv("tiving.csv")

engine = create_engine(
    f"mysql+mysqlconnector://{mysql_config['user']}:{mysql_config['password']}@{mysql_config['host']}:{mysql_config['port']}/{mysql_config['database']}"
)

table_name = 'tiving' 
tiving.to_sql(table_name, con=engine, if_exists='replace', index=True)
# Out:
# 20

# %% [markdown]
# ### 7. SQL 연결 종료

# %%
engine.dispose()
